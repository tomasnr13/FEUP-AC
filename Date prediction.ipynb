# %%
import pandas as pd
import numpy as nm

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV, cross_val_score

from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
import numpy as np

from sklearn import preprocessing

from collections import Counter
import seaborn as sb

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

from sklearn.preprocessing import StandardScaler

from sklearn.tree import DecisionTreeClassifier
import warnings
warnings.filterwarnings('always')  # "error", "ignore", "always", "default", "module" or "once"
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Dataset

# %%
account = pd.read_csv("ficheiros_competicao_dev/account.csv")
cards = pd.read_csv("ficheiros_competicao_dev/card_dev.csv")
clients = pd.read_csv("ficheiros_competicao_dev/client.csv")
disps = pd.read_csv("ficheiros_competicao_dev/disp.csv")
districts = pd.read_csv("ficheiros_competicao_dev/district.csv")
loans = pd.read_csv("ficheiros_competicao_dev/loan_dev.csv")
trans = pd.read_csv("ficheiros_competicao_dev/trans_dev.csv")

dataset = account.rename({'frequency' : 'frequency_account', 'date' : 'date_of_creation'}, axis=1)

dataset = dataset.merge(loans) 
dataset.drop('loan_id', inplace=True, axis=1)
dataset = dataset.rename({'date' : 'date_of_loan', 'duration' : 'duration_loan', 'payments' : 'payments_loan', 'status' : 'status_loan'}, axis=1)

dataset = dataset.merge(pd.DataFrame(trans.groupby('account_id').size(), columns=['n.of trans']), left_on='account_id', right_index=True, how="outer")
dataset = dataset.merge(pd.DataFrame(trans[trans['operation']=='credit in cash'].groupby('account_id').size(), columns=['credit_cash']), right_index=True, left_on='account_id', how="outer")
dataset = dataset.merge(pd.DataFrame(trans[trans['operation']=='credit card withdrawal'].groupby('account_id').size(), columns=['cc_wdw']), right_index=True, left_on='account_id', how="outer")
dataset = dataset.merge(pd.DataFrame(trans[trans['operation']=='withdrawal in cash'].groupby('account_id').size(), columns=['wdw_cash']), right_index=True, left_on='account_id', how="outer")
dataset = dataset.merge(pd.DataFrame(trans[trans['operation']=='collection from another bank'].groupby('account_id').size(), columns=['coll_bank']), right_index=True, left_on='account_id', how="outer")
dataset = dataset.merge(pd.DataFrame(trans[trans['operation']=='remittance to another bank'].groupby('account_id').size(), columns=['rem_bank']), right_index=True, left_on='account_id', how="outer")
dataset = dataset.merge(pd.DataFrame(trans[trans['type']=='withdrawal'].groupby('account_id').size(), columns=['type #1']), right_index=True, left_on='account_id', how="outer")
dataset = dataset.merge(pd.DataFrame(trans[trans['type']=='withdrawal in cash'].groupby('account_id').size(), columns=['type #2']), right_index=True, left_on='account_id', how="outer")
dataset = dataset.merge(pd.DataFrame(trans[trans['type']=='credit'].groupby('account_id').size(), columns=['type #3']), right_index=True, left_on='account_id', how="outer")

dataset = dataset.merge(pd.DataFrame(trans.groupby('account_id').amount.mean().round(2)).rename(columns={'amount':'avg trans amount'}), right_index=True, left_on='account_id', how="outer")
dataset = dataset.merge(pd.DataFrame(trans.groupby('account_id').balance.mean().round(2)).rename(columns={'balance':'avg trans balance'}), right_index=True, left_on='account_id', how="outer")

# dataset = dataset.merge(disps, how="outer")

# dataset = dataset.merge(cards, how="outer")
# dataset = dataset.rename({'type' : 'card_type'}, axis=1)
# dataset.drop('disp_id', inplace=True, axis=1)

# dataset = dataset.merge(clients, left_on="client_id", right_on="client_id") 
# dataset = dataset.rename({'district_id_x' : 'district_id_account', 'district_id_y' : 'district_id_client'}, axis=1)
# dataset = dataset.merge(districts, left_on = "district_id_client", right_on="district_id")

dataset = dataset.merge(districts)


disps = disps.rename(columns={"type": "disp type"})
disps['has disponent'] = nm.where(disps['disp type'] == 'DISPONENT', True, False)
cards = cards.rename(columns={"type": "card type"})
disp_card = pd.merge(disps, cards, how="outer")

disp_card_clients = pd.merge(disp_card, clients).drop_duplicates(subset=['account_id']).drop(columns=['has disponent', 'disp type', 'disp_id'])
temp = pd.merge(disp_card_clients, pd.DataFrame(disp_card.groupby('account_id').size(), columns = ['count owner']), right_index=True, left_on='account_id', how="outer")
disp_card_clients['has disponent'] = nm.where(temp['count owner'] == 2, True, False)

dataset = dataset.merge(disp_card_clients)

dataset.to_csv("ligma")

# %% [markdown]
# ##  Pre Processing

# %%
def nulls(dataset, jcolumns):
    for col in jcolumns:
        if(col in dataset.columns.tolist()):
            for row in range(0,len(dataset)):
                if dataset.iloc[row][col] is None:
                    dataset.drop(row, axis=0, inplace=True)
        else:
            print('Error: column ' + col + ' does not exist in dataset')
    dataset.fillna(0) 
    return dataset

def checknullcolumns(dataset):
    print("Number of null values:" + str(dataset.isna().sum().sum()))
    for col in dataset.columns.values.tolist():
        print("number of null rows in " + col)
        print(dataset[col].isna().sum())

# %%
# dataset = nulls(dataset, ['account_id','client_id', 'card_id'])

# checknullcolumns(dataset)

for col in ['cc_wdw', 'wdw_cash', 'coll_bank', 'rem_bank', 'credit_cash', 'type #1', 'type #2', 'type #3']:
    dataset[col] = dataset[col].fillna(0)

dataset = dataset.drop(columns=['issued', 'card type', 'card_id'])

checknullcolumns(dataset)
# Out:
# Number of null values:0
# number of null rows in account_id
# 0
# number of null rows in district_id
# 0
# number of null rows in frequency_account
# 0
# number of null rows in date_of_creation
# 0
# number of null rows in date_of_loan
# 0
# number of null rows in amount
# 0
# number of null rows in duration_loan
# 0
# number of null rows in payments_loan
# 0
# number of null rows in status_loan
# 0
# number of null rows in n.of trans
# 0
# number of null rows in credit_cash
# 0
# number of null rows in cc_wdw
# 0
# number of null rows in wdw_cash
# 0
# number of null rows in coll_bank
# 0
# number of null rows in rem_bank
# 0
# number of null rows in type #1
# 0
# number of null rows in type #2
# 0
# number of null rows in type #3
# 0
# number of null rows in avg trans amount
# 0
# number of null rows in avg trans balance
# 0
# number of null rows in name
# 0
# number of null rows in region
# 0
# number of null rows in no. of inhabitants
# 0
# number of null rows in no. of municipalities with inhabitants < 499
# 0
# number of null rows in no. of municipalities with inhabitants 500-1999
# 0
# number of null rows in no. of municipalities with inhabitants 2000-9999
# 0
# number of null rows in no. of municipalities with inhabitants >10000
# 0
# number of null rows in no. of cities
# 0
# number of null rows in ratio of urban inhabitants
# 0
# number of null rows in average salary
# 0
# number of null rows in unemploymant rate '95
# 0
# number of null rows in unemploymant rate '96
# 0
# number of null rows in no. of enterpreneurs per 1000 inhabitants
# 0
# number of null rows in no. of commited crimes '95
# 0
# number of null rows in no. of commited crimes '96
# 0
# number of null rows in client_id
# 0
# number of null rows in birth_number
# 0
# number of null rows in has disponent
# 0

# %%
dataset.info
# Out:
# <bound method DataFrame.info of      account_id  district_id frequency_account  date_of_creation  \
# 0          5270         44.0  monthly issuance          930113.0
# 1          5385         44.0   weekly issuance          930521.0
# 2          3037         44.0  monthly issuance          940526.0
# 3         10942         44.0   weekly issuance          940605.0
# 4         11265         15.0  monthly issuance          930114.0
# ..          ...          ...               ...               ...
# 263        4462         73.0   weekly issuance          951227.0
# 264        5001         53.0  monthly issuance          951215.0
# 265        3084         59.0   weekly issuance          960128.0
# 266       11054         59.0   weekly issuance          960201.0
# 267        8680         17.0  monthly issuance          960212.0
#
#      date_of_loan    amount  duration_loan  payments_loan  status_loan  \
# 0        931122.0   79608.0           24.0         3317.0          1.0
# 1        940407.0  149340.0           60.0         2489.0          1.0
# 2        960418.0  277884.0           36.0         7719.0         -1.0
# 3        951002.0  314520.0           60.0         5242.0          1.0
# 4        930915.0   52788.0           12.0         4399.0          1.0
# ..            ...       ...            ...            ...          ...
# 263      960514.0   66480.0           24.0         2770.0         -1.0
# 264      961109.0  110112.0           24.0         4588.0          1.0
# 265      960828.0  253512.0           36.0         7042.0         -1.0
# 266      960820.0  148920.0           60.0         2482.0          1.0
# 267      960714.0   85716.0           36.0         2381.0          1.0
#
#      n.of trans  ...  ratio of urban inhabitants  average salary  \
# 0            53  ...                        53.0            8254
# 1            56  ...                        53.0            8254
# 2           117  ...                        53.0            8254
# 3           130  ...                        53.0            8254
# 4            43  ...                        51.9            9045
# ..          ...  ...                         ...             ...
# 263          10  ...                        56.4            8746
# 264          82  ...                        50.9            8240
# 265          29  ...                        62.1            8444
# 266          31  ...                        62.1            8444
# 267          19  ...                        61.4            8114
#
#      unemploymant rate '95  unemploymant rate '96  \
# 0                     2.79                   3.76
# 1                     2.79                   3.76
# 2                     2.79                   3.76
# 3                     2.79                   3.76
# 4                     3.13                   3.60
# ..                     ...                    ...
# 263                   3.33                   3.74
# 264                   2.53                   3.56
# 265                   3.24                   3.47
# 266                   3.24                   3.47
# 267                   2.38                   2.62
#
#      no. of enterpreneurs per 1000 inhabitants  no. of commited crimes '95  \
# 0                                           97                        2166
# 1                                           97                        2166
# 2                                           97                        2166
# 3                                           97                        2166
# 4                                          124                        1845
# ..                                         ...                         ...
# 263                                         90                        4355
# 264                                         99                        1850
# 265                                        106                        2595
# 266                                        106                        2595
# 267                                        119                        1003
#
#      no. of commited crimes '96   client_id  birth_number  has disponent
# 0                           2325       6367        700428          False
# 1                           2325       6499        630201          False
# 2                           2325       3670        805917          False
# 3                           2325      13451        556118          False
# 4                           1879      13845        730216          False
# ..                           ...        ...           ...            ...
# 263                         4433       5384        350721          False
# 264                         1903       6042        631012          False
# 265                         2305       3730        455807          False
# 266                         2305      13590        770803          False
# 267                         1181      10702        380503           True
#
# [268 rows x 38 columns]>

# %%
dataset.dtypes
# Out:
# account_id                                            int64
# district_id                                         float64
# frequency_account                                    object
# date_of_creation                                    float64
# date_of_loan                                        float64
# amount                                              float64
# duration_loan                                       float64
# payments_loan                                       float64
# status_loan                                         float64
# n.of trans                                            int64
# credit_cash                                           int64
# cc_wdw                                              float64
# wdw_cash                                            float64
# coll_bank                                           float64
# rem_bank                                            float64
# type #1                                             float64
# type #2                                             float64
# type #3                                               int64
# avg trans amount                                    float64
# avg trans balance                                   float64
# name                                                 object
# region                                               object
# no. of inhabitants                                    int64
# no. of municipalities with inhabitants < 499          int64
# no. of municipalities with inhabitants 500-1999       int64
# no. of municipalities with inhabitants 2000-9999      int64
# no. of municipalities with inhabitants >10000         int64
# no. of cities                                         int64
# ratio of urban inhabitants                          float64
# average salary                                        int64
# unemploymant rate '95                                object
# unemploymant rate '96                               float64
# no. of enterpreneurs per 1000 inhabitants             int64
# no. of commited crimes '95                           object
# no. of commited crimes '96                            int64
# client_id                                             int64
# birth_number                                          int64
# has disponent                                          bool
# dtype: object

# %%
# Creating correlation matrix
dataset_corr = dataset.corr().abs()
dataset_corr
# Out:
#                                                   account_id  district_id  \
# account_id                                          1.000000     0.039562
# district_id                                         0.039562     1.000000
# date_of_creation                                    0.030956     0.024400
# date_of_loan                                        0.060458     0.038526
# amount                                              0.023877     0.027119
# duration_loan                                       0.001406     0.071698
# payments_loan                                       0.031709     0.027257
# status_loan                                         0.099614     0.010076
# n.of trans                                          0.070785     0.000580
# credit_cash                                         0.048214     0.041173
# cc_wdw                                              0.002020     0.052704
# wdw_cash                                            0.046701     0.015819
# coll_bank                                           0.016081     0.039615
# rem_bank                                            0.022268     0.049554
# type #1                                             0.036581     0.012282
# type #2                                             0.086290     0.033397
# type #3                                             0.116753     0.014758
# avg trans amount                                    0.000206     0.050890
# avg trans balance                                   0.068318     0.049525
# no. of inhabitants                                  0.112249     0.457518
# no. of municipalities with inhabitants < 499        0.035030     0.046659
# no. of municipalities with inhabitants 500-1999     0.013894     0.439685
# no. of municipalities with inhabitants 2000-9999    0.002259     0.393376
# no. of municipalities with inhabitants >10000       0.005587     0.402212
# no. of cities                                       0.038227     0.240566
# ratio of urban inhabitants                          0.103150     0.185166
# average salary                                      0.113278     0.465074
# unemploymant rate '96                               0.050771     0.553364
# no. of enterpreneurs per 1000 inhabitants           0.071100     0.636465
# no. of commited crimes '96                          0.099782     0.522394
# client_id                                           0.999886     0.040016
# birth_number                                        0.104163     0.098483
# has disponent                                       0.045247     0.038792
#
#                                                   date_of_creation  \
# account_id                                                0.030956
# district_id                                               0.024400
# date_of_creation                                          1.000000
# date_of_loan                                              0.815511
# amount                                                    0.024643
# duration_loan                                             0.068419
# payments_loan                                             0.004793
# status_loan                                               0.056623
# n.of trans                                                0.307901
# credit_cash                                               0.212791
# cc_wdw                                                    0.017927
# wdw_cash                                                  0.314751
# coll_bank                                                 0.051408
# rem_bank                                                  0.151624
# type #1                                                   0.286745
# type #2                                                   0.211981
# type #3                                                   0.300322
# avg trans amount                                          0.115414
# avg trans balance                                         0.042510
# no. of inhabitants                                        0.016855
# no. of municipalities with inhabitants < 499              0.020192
# no. of municipalities with inhabitants 500-1999           0.012764
# no. of municipalities with inhabitants 2000-9999          0.057808
# no. of municipalities with inhabitants >10000             0.196947
# no. of cities                                             0.046330
# ratio of urban inhabitants                                0.020089
# average salary                                            0.009026
# unemploymant rate '96                                     0.057849
# no. of enterpreneurs per 1000 inhabitants                 0.062210
# no. of commited crimes '96                                0.027733
# client_id                                                 0.031312
# birth_number                                              0.022628
# has disponent                                             0.004113
#
#                                                   date_of_loan    amount  \
# account_id                                            0.060458  0.023877
# district_id                                           0.038526  0.027119
# date_of_creation                                      0.815511  0.024643
# date_of_loan                                          1.000000  0.101325
# amount                                                0.101325  1.000000
# duration_loan                                         0.167922  0.581755
# payments_loan                                         0.002600  0.718617
# status_loan                                           0.046012  0.092365
# n.of trans                                            0.160304  0.085621
# credit_cash                                           0.072419  0.094660
# cc_wdw                                                0.055184  0.023752
# wdw_cash                                              0.153591  0.140126
# coll_bank                                             0.056043  0.061994
# rem_bank                                              0.113427  0.103312
# type #1                                               0.168235  0.047192
# type #2                                               0.011684  0.131085
# type #3                                               0.140501  0.130314
# avg trans amount                                      0.033645  0.239460
# avg trans balance                                     0.079355  0.128023
# no. of inhabitants                                    0.049578  0.006330
# no. of municipalities with inhabitants < 499          0.057604  0.079181
# no. of municipalities with inhabitants 500-1999       0.013033  0.081202
# no. of municipalities with inhabitants 2000-9999      0.032585  0.015339
# no. of municipalities with inhabitants >10000         0.157309  0.021444
# no. of cities                                         0.102569  0.009881
# ratio of urban inhabitants                            0.000996  0.041666
# average salary                                        0.053961  0.000531
# unemploymant rate '96                                 0.088609  0.009774
# no. of enterpreneurs per 1000 inhabitants             0.080289  0.015488
# no. of commited crimes '96                            0.057486  0.005835
# client_id                                             0.061229  0.023693
# birth_number                                          0.044283  0.083667
# has disponent                                         0.026010  0.051076
#
#                                                   duration_loan  \
# account_id                                             0.001406
# district_id                                            0.071698
# date_of_creation                                       0.068419
# date_of_loan                                           0.167922
# amount                                                 0.581755
# duration_loan                                          1.000000
# payments_loan                                          0.039838
# status_loan                                            0.049515
# n.of trans                                             0.097854
# credit_cash                                            0.145629
# cc_wdw                                                 0.059200
# wdw_cash                                               0.107202
# coll_bank                                              0.066482
# rem_bank                                               0.001900
# type #1                                                0.091516
# type #2                                                0.066486
# type #3                                                0.121607
# avg trans amount                                       0.042411
# avg trans balance                                      0.000915
# no. of inhabitants                                     0.073794
# no. of municipalities with inhabitants < 499           0.051413
# no. of municipalities with inhabitants 500-1999        0.027433
# no. of municipalities with inhabitants 2000-9999       0.006221
# no. of municipalities with inhabitants >10000          0.001415
# no. of cities                                          0.024975
# ratio of urban inhabitants                             0.041896
# average salary                                         0.061882
# unemploymant rate '96                                  0.010226
# no. of enterpreneurs per 1000 inhabitants              0.026260
# no. of commited crimes '96                             0.077691
# client_id                                              0.001850
# birth_number                                           0.081607
# has disponent                                          0.072132
#
#                                                   payments_loan  status_loan  \
# account_id                                             0.031709     0.099614
# district_id                                            0.027257     0.010076
# date_of_creation                                       0.004793     0.056623
# date_of_loan                                           0.002600     0.046012
# amount                                                 0.718617     0.092365
# duration_loan                                          0.039838     0.049515
# payments_loan                                          1.000000     0.166712
# status_loan                                            0.166712     1.000000
# n.of trans                                             0.000261     0.104216
# credit_cash                                            0.028534     0.031793
# cc_wdw                                                 0.063457     0.049094
# wdw_cash                                               0.053660     0.081382
# coll_bank                                              0.112380     0.142081
# rem_bank                                               0.129845     0.185347
# type #1                                                0.038447     0.140228
# type #2                                                0.193108     0.052772
# type #3                                                0.032866     0.024159
# avg trans amount                                       0.297515     0.063329
# avg trans balance                                      0.140991     0.223042
# no. of inhabitants                                     0.001141     0.009761
# no. of municipalities with inhabitants < 499           0.070330     0.087907
# no. of municipalities with inhabitants 500-1999        0.100048     0.075799
# no. of municipalities with inhabitants 2000-9999       0.020964     0.013420
# no. of municipalities with inhabitants >10000          0.044568     0.062085
# no. of cities                                          0.050143     0.052480
# ratio of urban inhabitants                             0.051555     0.021200
# average salary                                         0.000358     0.023856
# unemploymant rate '96                                  0.018044     0.024179
# no. of enterpreneurs per 1000 inhabitants              0.024082     0.021605
# no. of commited crimes '96                             0.000700     0.012991
# client_id                                              0.030350     0.100180
# birth_number                                           0.016033     0.043791
# has disponent                                          0.021442     0.224166
#
#                                                   n.of trans  credit_cash  \
# account_id                                          0.070785     0.048214
# district_id                                         0.000580     0.041173
# date_of_creation                                    0.307901     0.212791
# date_of_loan                                        0.160304     0.072419
# amount                                              0.085621     0.094660
# duration_loan                                       0.097854     0.145629
# payments_loan                                       0.000261     0.028534
# status_loan                                         0.104216     0.031793
# n.of trans                                          1.000000     0.631869
# credit_cash                                         0.631869     1.000000
# cc_wdw                                              0.141304     0.055482
# wdw_cash                                            0.950892     0.590177
# coll_bank                                           0.199631     0.546396
# rem_bank                                            0.668444     0.281598
# type #1                                             0.973379     0.547650
# type #2                                             0.530028     0.297034
# type #3                                             0.927944     0.720873
# avg trans amount                                    0.088083     0.072891
# avg trans balance                                   0.164602     0.139093
# no. of inhabitants                                  0.007627     0.015642
# no. of municipalities with inhabitants < 499        0.101666     0.041620
# no. of municipalities with inhabitants 500-1999     0.010515     0.007785
# no. of municipalities with inhabitants 2000-9999    0.046722     0.045237
# no. of municipalities with inhabitants >10000       0.051513     0.061180
# no. of cities                                       0.108900     0.074625
# ratio of urban inhabitants                          0.024016     0.065628
# average salary                                      0.036815     0.003542
# unemploymant rate '96                               0.023098     0.006743
# no. of enterpreneurs per 1000 inhabitants           0.042326     0.043155
# no. of commited crimes '96                          0.006193     0.013388
# client_id                                           0.070924     0.047934
# birth_number                                        0.043722     0.048441
# has disponent                                       0.061984     0.027023
#
#                                                   ...  \
# account_id                                        ...
# district_id                                       ...
# date_of_creation                                  ...
# date_of_loan                                      ...
# amount                                            ...
# duration_loan                                     ...
# payments_loan                                     ...
# status_loan                                       ...
# n.of trans                                        ...
# credit_cash                                       ...
# cc_wdw                                            ...
# wdw_cash                                          ...
# coll_bank                                         ...
# rem_bank                                          ...
# type #1                                           ...
# type #2                                           ...
# type #3                                           ...
# avg trans amount                                  ...
# avg trans balance                                 ...
# no. of inhabitants                                ...
# no. of municipalities with inhabitants < 499      ...
# no. of municipalities with inhabitants 500-1999   ...
# no. of municipalities with inhabitants 2000-9999  ...
# no. of municipalities with inhabitants >10000     ...
# no. of cities                                     ...
# ratio of urban inhabitants                        ...
# average salary                                    ...
# unemploymant rate '96                             ...
# no. of enterpreneurs per 1000 inhabitants         ...
# no. of commited crimes '96                        ...
# client_id                                         ...
# birth_number                                      ...
# has disponent                                     ...
#
#                                                   no. of municipalities with inhabitants >10000  \
# account_id                                                                             0.005587
# district_id                                                                            0.402212
# date_of_creation                                                                       0.196947
# date_of_loan                                                                           0.157309
# amount                                                                                 0.021444
# duration_loan                                                                          0.001415
# payments_loan                                                                          0.044568
# status_loan                                                                            0.062085
# n.of trans                                                                             0.051513
# credit_cash                                                                            0.061180
# cc_wdw                                                                                 0.129055
# wdw_cash                                                                               0.054775
# coll_bank                                                                              0.003973
# rem_bank                                                                               0.011711
# type #1                                                                                0.048452
# type #2                                                                                0.014995
# type #3                                                                                0.053457
# avg trans amount                                                                       0.196584
# avg trans balance                                                                      0.190077
# no. of inhabitants                                                                     0.173147
# no. of municipalities with inhabitants < 499                                           0.057202
# no. of municipalities with inhabitants 500-1999                                        0.152207
# no. of municipalities with inhabitants 2000-9999                                       0.145617
# no. of municipalities with inhabitants >10000                                          1.000000
# no. of cities                                                                          0.273397
# ratio of urban inhabitants                                                             0.070453
# average salary                                                                         0.156461
# unemploymant rate '96                                                                  0.464333
# no. of enterpreneurs per 1000 inhabitants                                              0.430830
# no. of commited crimes '96                                                             0.212470
# client_id                                                                              0.006449
# birth_number                                                                           0.011141
# has disponent                                                                          0.018012
#
#                                                   no. of cities  \
# account_id                                             0.038227
# district_id                                            0.240566
# date_of_creation                                       0.046330
# date_of_loan                                           0.102569
# amount                                                 0.009881
# duration_loan                                          0.024975
# payments_loan                                          0.050143
# status_loan                                            0.052480
# n.of trans                                             0.108900
# credit_cash                                            0.074625
# cc_wdw                                                 0.047052
# wdw_cash                                               0.101469
# coll_bank                                              0.036904
# rem_bank                                               0.055254
# type #1                                                0.097144
# type #2                                                0.059171
# type #3                                                0.117441
# avg trans amount                                       0.013734
# avg trans balance                                      0.065524
# no. of inhabitants                                     0.590140
# no. of municipalities with inhabitants < 499           0.385459
# no. of municipalities with inhabitants 500-1999        0.594047
# no. of municipalities with inhabitants 2000-9999       0.720627
# no. of municipalities with inhabitants >10000          0.273397
# no. of cities                                          1.000000
# ratio of urban inhabitants                             0.459345
# average salary                                         0.578550
# unemploymant rate '96                                  0.115034
# no. of enterpreneurs per 1000 inhabitants              0.351356
# no. of commited crimes '96                             0.600521
# client_id                                              0.037611
# birth_number                                           0.050349
# has disponent                                          0.033778
#
#                                                   ratio of urban inhabitants  \
# account_id                                                          0.103150
# district_id                                                         0.185166
# date_of_creation                                                    0.020089
# date_of_loan                                                        0.000996
# amount                                                              0.041666
# duration_loan                                                       0.041896
# payments_loan                                                       0.051555
# status_loan                                                         0.021200
# n.of trans                                                          0.024016
# credit_cash                                                         0.065628
# cc_wdw                                                              0.078327
# wdw_cash                                                            0.008634
# coll_bank                                                           0.082014
# rem_bank                                                            0.010824
# type #1                                                             0.009718
# type #2                                                             0.000164
# type #3                                                             0.050531
# avg trans amount                                                    0.010242
# avg trans balance                                                   0.028547
# no. of inhabitants                                                  0.691478
# no. of municipalities with inhabitants < 499                        0.624413
# no. of municipalities with inhabitants 500-1999                     0.748624
# no. of municipalities with inhabitants 2000-9999                    0.565858
# no. of municipalities with inhabitants >10000                       0.070453
# no. of cities                                                       0.459345
# ratio of urban inhabitants                                          1.000000
# average salary                                                      0.791369
# unemploymant rate '96                                               0.138213
# no. of enterpreneurs per 1000 inhabitants                           0.378780
# no. of commited crimes '96                                          0.661266
# client_id                                                           0.103572
# birth_number                                                        0.040944
# has disponent                                                       0.016686
#
#                                                   average salary  \
# account_id                                              0.113278
# district_id                                             0.465074
# date_of_creation                                        0.009026
# date_of_loan                                            0.053961
# amount                                                  0.000531
# duration_loan                                           0.061882
# payments_loan                                           0.000358
# status_loan                                             0.023856
# n.of trans                                              0.036815
# credit_cash                                             0.003542
# cc_wdw                                                  0.036523
# wdw_cash                                                0.039386
# coll_bank                                               0.048676
# rem_bank                                                0.046175
# type #1                                                 0.050035
# type #2                                                 0.014067
# type #3                                                 0.008516
# avg trans amount                                        0.008945
# avg trans balance                                       0.030964
# no. of inhabitants                                      0.908684
# no. of municipalities with inhabitants < 499            0.596451
# no. of municipalities with inhabitants 500-1999         0.620336
# no. of municipalities with inhabitants 2000-9999        0.480001
# no. of municipalities with inhabitants >10000           0.156461
# no. of cities                                           0.578550
# ratio of urban inhabitants                              0.791369
# average salary                                          1.000000
# unemploymant rate '96                                   0.412465
# no. of enterpreneurs per 1000 inhabitants               0.654443
# no. of commited crimes '96                              0.899675
# client_id                                               0.113227
# birth_number                                            0.037187
# has disponent                                           0.019829
#
#                                                   unemploymant rate '96  \
# account_id                                                     0.050771
# district_id                                                    0.553364
# date_of_creation                                               0.057849
# date_of_loan                                                   0.088609
# amount                                                         0.009774
# duration_loan                                                  0.010226
# payments_loan                                                  0.018044
# status_loan                                                    0.024179
# n.of trans                                                     0.023098
# credit_cash                                                    0.006743
# cc_wdw                                                         0.011762
# wdw_cash                                                       0.035451
# coll_bank                                                      0.044437
# rem_bank                                                       0.042133
# type #1                                                        0.010945
# type #2                                                        0.020499
# type #3                                                        0.049740
# avg trans amount                                               0.100547
# avg trans balance                                              0.084281
# no. of inhabitants                                             0.503449
# no. of municipalities with inhabitants < 499                   0.070908
# no. of municipalities with inhabitants 500-1999                0.088081
# no. of municipalities with inhabitants 2000-9999               0.085605
# no. of municipalities with inhabitants >10000                  0.464333
# no. of cities                                                  0.115034
# ratio of urban inhabitants                                     0.138213
# average salary                                                 0.412465
# unemploymant rate '96                                          1.000000
# no. of enterpreneurs per 1000 inhabitants                      0.748664
# no. of commited crimes '96                                     0.512735
# client_id                                                      0.050492
# birth_number                                                   0.075873
# has disponent                                                  0.008078
#
#                                                   no. of enterpreneurs per 1000 inhabitants  \
# account_id                                                                         0.071100
# district_id                                                                        0.636465
# date_of_creation                                                                   0.062210
# date_of_loan                                                                       0.080289
# amount                                                                             0.015488
# duration_loan                                                                      0.026260
# payments_loan                                                                      0.024082
# status_loan                                                                        0.021605
# n.of trans                                                                         0.042326
# credit_cash                                                                        0.043155
# cc_wdw                                                                             0.068632
# wdw_cash                                                                           0.034100
# coll_bank                                                                          0.014176
# rem_bank                                                                           0.004068
# type #1                                                                            0.024946
# type #2                                                                            0.019346
# type #3                                                                            0.078276
# avg trans amount                                                                   0.118667
# avg trans balance                                                                  0.105311
# no. of inhabitants                                                                 0.706869
# no. of municipalities with inhabitants < 499                                       0.308357
# no. of municipalities with inhabitants 500-1999                                    0.308153
# no. of municipalities with inhabitants 2000-9999                                   0.369029
# no. of municipalities with inhabitants >10000                                      0.430830
# no. of cities                                                                      0.351356
# ratio of urban inhabitants                                                         0.378780
# average salary                                                                     0.654443
# unemploymant rate '96                                                              0.748664
# no. of enterpreneurs per 1000 inhabitants                                          1.000000
# no. of commited crimes '96                                                         0.725984
# client_id                                                                          0.071354
# birth_number                                                                       0.042868
# has disponent                                                                      0.006229
#
#                                                   no. of commited crimes '96   \
# account_id                                                           0.099782
# district_id                                                          0.522394
# date_of_creation                                                     0.027733
# date_of_loan                                                         0.057486
# amount                                                               0.005835
# duration_loan                                                        0.077691
# payments_loan                                                        0.000700
# status_loan                                                          0.012991
# n.of trans                                                           0.006193
# credit_cash                                                          0.013388
# cc_wdw                                                               0.040744
# wdw_cash                                                             0.009912
# coll_bank                                                            0.041478
# rem_bank                                                             0.012273
# type #1                                                              0.011946
# type #2                                                              0.018734
# type #3                                                              0.008501
# avg trans amount                                                     0.014299
# avg trans balance                                                    0.033157
# no. of inhabitants                                                   0.994542
# no. of municipalities with inhabitants < 499                         0.488432
# no. of municipalities with inhabitants 500-1999                      0.540885
# no. of municipalities with inhabitants 2000-9999                     0.504069
# no. of municipalities with inhabitants >10000                        0.212470
# no. of cities                                                        0.600521
# ratio of urban inhabitants                                           0.661266
# average salary                                                       0.899675
# unemploymant rate '96                                                0.512735
# no. of enterpreneurs per 1000 inhabitants                            0.725984
# no. of commited crimes '96                                           1.000000
# client_id                                                            0.099728
# birth_number                                                         0.063047
# has disponent                                                        0.008605
#
#                                                   client_id  birth_number  \
# account_id                                         0.999886      0.104163
# district_id                                        0.040016      0.098483
# date_of_creation                                   0.031312      0.022628
# date_of_loan                                       0.061229      0.044283
# amount                                             0.023693      0.083667
# duration_loan                                      0.001850      0.081607
# payments_loan                                      0.030350      0.016033
# status_loan                                        0.100180      0.043791
# n.of trans                                         0.070924      0.043722
# credit_cash                                        0.047934      0.048441
# cc_wdw                                             0.003404      0.021459
# wdw_cash                                           0.046496      0.056557
# coll_bank                                          0.016691      0.013529
# rem_bank                                           0.021848      0.011210
# type #1                                            0.036103      0.036833
# type #2                                            0.087823      0.019426
# type #3                                            0.117743      0.052107
# avg trans amount                                   0.000412      0.044622
# avg trans balance                                  0.067888      0.039303
# no. of inhabitants                                 0.112246      0.057408
# no. of municipalities with inhabitants < 499       0.036172      0.060466
# no. of municipalities with inhabitants 500-1999    0.013735      0.066759
# no. of municipalities with inhabitants 2000-9999   0.001312      0.021440
# no. of municipalities with inhabitants >10000      0.006449      0.011141
# no. of cities                                      0.037611      0.050349
# ratio of urban inhabitants                         0.103572      0.040944
# average salary                                     0.113227      0.037187
# unemploymant rate '96                              0.050492      0.075873
# no. of enterpreneurs per 1000 inhabitants          0.071354      0.042868
# no. of commited crimes '96                         0.099728      0.063047
# client_id                                          1.000000      0.102255
# birth_number                                       0.102255      1.000000
# has disponent                                      0.046612      0.034894
#
#                                                   has disponent
# account_id                                             0.045247
# district_id                                            0.038792
# date_of_creation                                       0.004113
# date_of_loan                                           0.026010
# amount                                                 0.051076
# duration_loan                                          0.072132
# payments_loan                                          0.021442
# status_loan                                            0.224166
# n.of trans                                             0.061984
# credit_cash                                            0.027023
# cc_wdw                                                 0.055007
# wdw_cash                                               0.077073
# coll_bank                                              0.123952
# rem_bank                                               0.020829
# type #1                                                0.054318
# type #2                                                0.121001
# type #3                                                0.051142
# avg trans amount                                       0.017138
# avg trans balance                                      0.068556
# no. of inhabitants                                     0.008941
# no. of municipalities with inhabitants < 499           0.007574
# no. of municipalities with inhabitants 500-1999        0.040453
# no. of municipalities with inhabitants 2000-9999       0.009164
# no. of municipalities with inhabitants >10000          0.018012
# no. of cities                                          0.033778
# ratio of urban inhabitants                             0.016686
# average salary                                         0.019829
# unemploymant rate '96                                  0.008078
# no. of enterpreneurs per 1000 inhabitants              0.006229
# no. of commited crimes '96                             0.008605
# client_id                                              0.046612
# birth_number                                           0.034894
# has disponent                                          1.000000
#
# [33 rows x 33 columns]

# %%
def binary_encode(df, column, positive_value):
    df = df.copy()
    df[column] = df[column].apply(lambda x : 1 if x == positive_value else 0)
    return df
    
def ordinal_encode(df, column, ordering):
    df = df.copy()
    df[column] = df[column].apply(lambda x : ordering.index(x))
    return df

def special_binary_encode(df, column, negative_value):
    df = df.copy()
    df['card_owner'] = df[column].apply(lambda x : 0 if x == negative_value else 1)
    df = df.drop(column, axis=1)
    return df
# Encode column of dataframe
def encode_column(df, column_to_encode):
    
    df_ = df.copy() # copy dataframe to avoid making changes to it inside the function
    label_encoder = preprocessing.LabelEncoder()
    label_encoder.fit(df_[column_to_encode].unique())
    df_[column_to_encode] = label_encoder.transform(df_[column_to_encode])
    
    return df_

# %%
 # Ordinal encode the frequency column
freq_ordering = [
    'monthly issuance',
    'weekly issuance',
    'issuance after transaction'
]
dataset = ordinal_encode(dataset, 'frequency_account', ordering=freq_ordering)

# Binary encode the card column (has or not card)
freq_ordering = [
    'monthly issuance',
    'weekly issuance',
    'issuance after transaction'
]

# %%
def district_processing(df):

    df = encode_column(df, 'name')
    df = encode_column(df, 'region')
    df.loc[df['no. of commited crimes \'95']=="?", 'no. of commited crimes \'95'] = pd.to_numeric( df[df['no. of commited crimes \'95'] != '?']['no. of commited crimes \'95'] ).median()
    median_unemploymant_95 = (df[df['unemploymant rate \'95'] != '?']['unemploymant rate \'95']).astype(float).median()
    df.loc[df['unemploymant rate \'95']=="?", 'unemploymant rate \'95'] = median_unemploymant_95

    return df

# %%
dataset = district_processing(dataset)
# Encode the label (loan status) column
label_mapping = {-1: 1, 1: 0}
dataset['status_loan'] = dataset['status_loan'].replace(label_mapping)
dataset
# Out:
#      account_id  district_id  frequency_account  date_of_creation  \
# 0          5270         44.0                  0          930113.0
# 1          5385         44.0                  1          930521.0
# 2          3037         44.0                  0          940526.0
# 3         10942         44.0                  1          940605.0
# 4         11265         15.0                  0          930114.0
# ..          ...          ...                ...               ...
# 263        4462         73.0                  1          951227.0
# 264        5001         53.0                  0          951215.0
# 265        3084         59.0                  1          960128.0
# 266       11054         59.0                  1          960201.0
# 267        8680         17.0                  0          960212.0
#
#      date_of_loan    amount  duration_loan  payments_loan  status_loan  \
# 0        931122.0   79608.0           24.0         3317.0          0.0
# 1        940407.0  149340.0           60.0         2489.0          0.0
# 2        960418.0  277884.0           36.0         7719.0          1.0
# 3        951002.0  314520.0           60.0         5242.0          0.0
# 4        930915.0   52788.0           12.0         4399.0          0.0
# ..            ...       ...            ...            ...          ...
# 263      960514.0   66480.0           24.0         2770.0          1.0
# 264      961109.0  110112.0           24.0         4588.0          0.0
# 265      960828.0  253512.0           36.0         7042.0          1.0
# 266      960820.0  148920.0           60.0         2482.0          0.0
# 267      960714.0   85716.0           36.0         2381.0          0.0
#
#      n.of trans  ...  ratio of urban inhabitants  average salary  \
# 0            53  ...                        53.0            8254
# 1            56  ...                        53.0            8254
# 2           117  ...                        53.0            8254
# 3           130  ...                        53.0            8254
# 4            43  ...                        51.9            9045
# ..          ...  ...                         ...             ...
# 263          10  ...                        56.4            8746
# 264          82  ...                        50.9            8240
# 265          29  ...                        62.1            8444
# 266          31  ...                        62.1            8444
# 267          19  ...                        61.4            8114
#
#      unemploymant rate '95  unemploymant rate '96  \
# 0                     2.79                   3.76
# 1                     2.79                   3.76
# 2                     2.79                   3.76
# 3                     2.79                   3.76
# 4                     3.13                   3.60
# ..                     ...                    ...
# 263                   3.33                   3.74
# 264                   2.53                   3.56
# 265                   3.24                   3.47
# 266                   3.24                   3.47
# 267                   2.38                   2.62
#
#      no. of enterpreneurs per 1000 inhabitants  no. of commited crimes '95  \
# 0                                           97                        2166
# 1                                           97                        2166
# 2                                           97                        2166
# 3                                           97                        2166
# 4                                          124                        1845
# ..                                         ...                         ...
# 263                                         90                        4355
# 264                                         99                        1850
# 265                                        106                        2595
# 266                                        106                        2595
# 267                                        119                        1003
#
#      no. of commited crimes '96   client_id  birth_number  has disponent
# 0                           2325       6367        700428          False
# 1                           2325       6499        630201          False
# 2                           2325       3670        805917          False
# 3                           2325      13451        556118          False
# 4                           1879      13845        730216          False
# ..                           ...        ...           ...            ...
# 263                         4433       5384        350721          False
# 264                         1903       6042        631012          False
# 265                         2305       3730        455807          False
# 266                         2305      13590        770803          False
# 267                         1181      10702        380503           True
#
# [268 rows x 38 columns]

# %% [markdown]
# ## Training

# %%
# Choosing the upper triangle of the correlation matrix
upper_triangle = dataset_corr.where(nm.triu(nm.ones(dataset_corr.shape), k=1).astype(bool))

# Looking for columns with correlation higher than 0.95
collumn_drop = [column for column in upper_triangle.columns if any(upper_triangle[column] > 0.95)]

# %%
# Scale X with a standard scaler
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(dataset), columns=dataset.columns)
y = dataset['status_loan'].copy()

X_train, X_test, y_train, y_test = train_test_split(X, y , train_size=0.8,random_state=123)
# labels

# y_train

# %%
{column: len(X[column].unique()) for column in X.columns}
# Out:
# {'account_id': 268,
#  'district_id': 70,
#  'frequency_account': 3,
#  'date_of_creation': 243,
#  'date_of_loan': 237,
#  'amount': 258,
#  'duration_loan': 5,
#  'payments_loan': 249,
#  'status_loan': 2,
#  'n.of trans': 135,
#  'credit_cash': 40,
#  'cc_wdw': 6,
#  'wdw_cash': 80,
#  'coll_bank': 21,
#  'rem_bank': 44,
#  'type #1': 94,
#  'type #2': 14,
#  'type #3': 64,
#  'avg trans amount': 268,
#  'avg trans balance': 268,
#  'name': 70,
#  'region': 8,
#  'no. of inhabitants': 70,
#  'no. of municipalities with inhabitants < 499': 52,
#  'no. of municipalities with inhabitants 500-1999': 33,
#  'no. of municipalities with inhabitants 2000-9999': 16,
#  'no. of municipalities with inhabitants >10000': 6,
#  'no. of cities': 11,
#  'ratio of urban inhabitants': 63,
#  'average salary': 70,
#  "unemploymant rate '95": 64,
#  "unemploymant rate '96": 66,
#  'no. of enterpreneurs per 1000 inhabitants': 44,
#  "no. of commited crimes '95": 68,
#  "no. of commited crimes '96 ": 69,
#  'client_id': 268,
#  'birth_number': 262,
#  'has disponent': 2}

# %%
np.bincount(y_train)
# Out:
# array([182,  32], dtype=int64)

# %%
sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(X_train, y_train)

# %%
np.bincount(y_res)
# Out:
# array([182, 182], dtype=int64)

# %% [markdown]
# # Testing models with default parameters

# %%
models = [
    SVC(probability=True),
    DecisionTreeClassifier(),
    MLPClassifier(),
]

# %%
model_names = [
    "Support Vector Machine",
    "         Decision Tree",
    "        Neural Network",
]

# %%
# Imbalanced Dataset

for model in models:
    model.fit(X_train, y_train)
    
for model, name in zip(models, model_names):
    print(name + ": {:.4f}%".format(model.score(X_test, y_test) * 100))
    y_pred = model.predict(X_test)
    # print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
# Out:
# Support Vector Machine: 100.0000%
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        49
#          1.0       1.00      1.00      1.00         5
#
#     accuracy                           1.00        54
#    macro avg       1.00      1.00      1.00        54
# weighted avg       1.00      1.00      1.00        54
#
#          Decision Tree: 100.0000%
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        49
#          1.0       1.00      1.00      1.00         5
#
#     accuracy                           1.00        54
#    macro avg       1.00      1.00      1.00        54
# weighted avg       1.00      1.00      1.00        54
#
#         Neural Network: 98.1481%
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99        49
#          1.0       1.00      0.80      0.89         5
#
#     accuracy                           0.98        54
#    macro avg       0.99      0.90      0.94        54
# weighted avg       0.98      0.98      0.98        54

# %%
# Balanced Dataset

for model in models:
    model.fit(X_res, y_res)

# %%
for model, name in zip(models, model_names):
    print(name + ": {:.4f}%".format(model.score(X_test, y_test) * 100))
    y_pred_1 = model.predict(X_test)
    print(confusion_matrix(y_test, y_pred_1))
    print(classification_report(y_test, y_pred_1))
    # model.predict_proba(X_test)
# Out:
# Support Vector Machine: 100.0000%
# [[49  0]
#  [ 0  5]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        49
#          1.0       1.00      1.00      1.00         5
#
#     accuracy                           1.00        54
#    macro avg       1.00      1.00      1.00        54
# weighted avg       1.00      1.00      1.00        54
#
#          Decision Tree: 100.0000%
# [[49  0]
#  [ 0  5]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        49
#          1.0       1.00      1.00      1.00         5
#
#     accuracy                           1.00        54
#    macro avg       1.00      1.00      1.00        54
# weighted avg       1.00      1.00      1.00        54
#
#         Neural Network: 96.2963%
# [[48  1]
#  [ 1  4]]
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.98      0.98        49
#          1.0       0.80      0.80      0.80         5
#
#     accuracy                           0.96        54
#    macro avg       0.89      0.89      0.89        54
# weighted avg       0.96      0.96      0.96        54
